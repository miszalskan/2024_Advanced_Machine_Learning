# %%
import numpy as np
from adam import LogisticRegressionAdam
from load_data import *
from sklearn.model_selection import train_test_split
import pandas as pd
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, balanced_accuracy_score
import matplotlib.pyplot as plt

# %%
X, y = load_phenome()
# X, y = load_diabetes()
# X, y = load_ozone_level()
# X, y = load_qsar_biodegradation()
# X, y = load_pc3_software_detect()
# X, y =
# X, y =
# X, y =

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=17)

# %%
X_train.shape
# Out:
# (4323, 5)

# %%
adam = LogisticRegressionAdam(epochs=2000, learning_rate=0.001, early_stopping=True, patience=50)
adam.train(X_train, y_train, X_test, y_test)
y_pred = adam.predict(X_test)
balanced_accuracy_score(y_test, y_pred)
# Out:
# 0.6846953176189916

# %%
fig, axs = plt.subplots(1, 2, figsize=(12, 6))

axs[0].plot(adam.train_losses, label='Train Loss')
axs[0].plot(adam.valid_losses, label='Validation Loss')
axs[0].set_xlabel('epoch')
axs[0].set_ylabel('loss')
axs[0].legend()

axs[1].plot(adam.train_balanced_accuracies, label='Train balanced accuracy')
axs[1].plot(adam.valid_balanced_accuracies, label='Validation balanced accuracy')
axs[1].set_xlabel('epoch')
axs[1].set_ylabel('balanced accuracy')
axs[1].legend()

plt.show()

# %% [markdown]
# # Logistic regression

# %%
clf = LogisticRegression()
clf.fit(X_train, y_train)
y_pred_ = clf.predict(X_test)
balanced_accuracy_score(y_test, y_pred_)
# Out:
# 0.6690957813208783
